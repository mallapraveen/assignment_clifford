# %% [markdown]
# ### LLM's

# %% [markdown]
# #### AWS

# %%
import boto3
import os

bedrock_runtime = boto3.client(
    service_name="bedrock-runtime",
    region_name="us-east-1",
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    aws_session_token=os.getenv("AWS_SESSION_TOKEN"),
)

from langchain_aws import ChatBedrock

model_id = "us.anthropic.claude-3-5-sonnet-20241022-v2:0"

claude_3_sonnet = ChatBedrock(
    client=bedrock_runtime,
    model_id=model_id,
)

# %% [markdown]
# ### Document Loaders

# %%
file_paths = [
    "../data/OJ_L_202401689_EN_TXT.pdf",
]

# %%
from langchain_community.document_loaders import DirectoryLoader, UnstructuredFileLoader

path = "../data"
loader = DirectoryLoader(
    path,
    glob="*.pdf",
    # loader_kwargs={
    #     "strategy": "hi_res",
    #     # "mode": "elements",
    #     # "chunking_strategy": "by_title",
    # },
)
docs = loader.load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

child_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1200, chunk_overlap=0, separators=["\n\n", "\n", " ", ""]
)

docs_splitter = child_splitter.split_documents(docs)

# %% [markdown]
# ### Test Dataset Generation

# %%
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-small-en-v1.5",
    encode_kwargs={"normalize_embeddings": True, "batch_size": 8},
)

generator_llm = LangchainLLMWrapper(claude_3_sonnet)

generator_embeddings = LangchainEmbeddingsWrapper(embeddings)

# %%
from ragas.testset import TestsetGenerator
from ragas.cost import CostCallbackHandler
from ragas import RunConfig

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
dataset = generator.generate_with_langchain_docs(
    docs_splitter,
    testset_size=50,
    run_config=RunConfig(timeout=180, max_retries=10, max_wait=180, seed=42),
)
# Out:
# Applying SummaryExtractor:   0%|          | 0/570 [00:00<?, ?it/s]
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages
in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/langchain_aws/llms/bedrock.py", line 918, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#   File "/Users/pmalla01/Desktop/assignment_clifford/env/lib/python3.10/site-packages/botocore/client.py", line 1031, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.ThrottlingException: An error occurred (ThrottlingException) when calling the InvokeModel operation (reached max retries: 4): Too many requests, please wait before trying again.
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       3 from ragas import RunConfig
#       5 generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
# ----> 6 dataset = generator.generate_with_langchain_docs(
#       7     docs_splitter,
#       8     testset_size=50,
#       9     run_config=RunConfig(timeout=180, max_retries=10, max_wait=180, seed=42),
#      10 )
#
# File ~/Desktop/assignment_clifford/env/lib/python3.10/site-packages/ragas/testset/synthesizers/generate.py:188, in TestsetGenerator.generate_with_langchain_docs(self, documents, testset_size, transforms, transforms_llm, transforms_embedding_model, query_distribution, run_config, callbacks, with_debugging_logs, raise_exceptions)
#     185 apply_transforms(kg, transforms)
#     186 self.knowledge_graph = kg
# --> 188 return self.generate(
#     189     testset_size=testset_size,
#     190     query_distribution=query_distribution,
#     191     run_config=run_config,
#     192     callbacks=callbacks,
#     193     with_debugging_logs=with_debugging_logs,
#     194     raise_exceptions=raise_exceptions,
#     195 )
#
# File ~/Desktop/assignment_clifford/env/lib/python3.10/site-packages/ragas/testset/synthesizers/generate.py:330, in TestsetGenerator.generate(self, testset_size, query_distribution, num_personas, run_config, batch_size, callbacks, token_usage_parser, with_debugging_logs, raise_exceptions)
#     327 if run_config is not None:
#     328     self.llm.set_run_config(run_config)
# --> 330 query_distribution = query_distribution or default_query_distribution(
#     331     self.llm, self.knowledge_graph
#     332 )
#     333 callbacks = callbacks or []
#     335 # dict to store any callbacks we define
#
# File ~/Desktop/assignment_clifford/env/lib/python3.10/site-packages/ragas/testset/synthesizers/__init__.py:30, in default_query_distribution(llm, kg)
#      28     available_queries = []
#      29     for query in default_queries:
# ---> 30         if query.get_node_clusters(kg):
#      31             available_queries.append(query)
#      32 else:
#
# File ~/Desktop/assignment_clifford/env/lib/python3.10/site-packages/ragas/testset/synthesizers/multi_hop/abstract.py:47, in MultiHopAbstractQuerySynthesizer.get_node_clusters(self, knowledge_graph)
#      45 def get_node_clusters(self, knowledge_graph: KnowledgeGraph) -> t.List[t.Set[Node]]:
# ---> 47     node_clusters = knowledge_graph.find_indirect_clusters(
#      48         relationship_condition=lambda rel: (
#      49             True if rel.get_property("summary_similarity") else False
#      50         ),
#      51         depth_limit=3,
#      52     )
#      53     logger.info("found %d clusters", len(node_clusters))
#      54     return node_clusters
#
# File ~/Desktop/assignment_clifford/env/lib/python3.10/site-packages/ragas/testset/graph.py:306, in KnowledgeGraph.find_indirect_clusters(self, relationship_condition, depth_limit)
#     304 for node in self.nodes:
#     305     initial_cluster = set()
# --> 306     dfs(node, initial_cluster, 0, (node,))
#     308 # Remove duplicates by converting clusters to frozensets
#     309 unique_clusters = [
#     310     set(cluster) for cluster in set(frozenset(c) for c in clusters)
#     311 ]
#
# File ~/Desktop/assignment_clifford/env/lib/python3.10/site-packages/ragas/testset/graph.py:298, in KnowledgeGraph.find_indirect_clusters.<locals>.dfs(node, cluster, depth, path)
#     295         neighbor = rel.source
#     297     if neighbor is not None:
# --> 298         dfs(neighbor, cluster.copy(), depth + 1, path + (neighbor,))
#     300 # Add completed path-based cluster
#     301 if len(cluster) > 1:
#
# File ~/Desktop/assignment_clifford/env/lib/python3.10/site-packages/ragas/testset/graph.py:298, in KnowledgeGraph.find_indirect_clusters.<locals>.dfs(node, cluster, depth, path)
#     295         neighbor = rel.source
#     297     if neighbor is not None:
# --> 298         dfs(neighbor, cluster.copy(), depth + 1, path + (neighbor,))
#     300 # Add completed path-based cluster
#     301 if len(cluster) > 1:
#
# File ~/Desktop/assignment_clifford/env/lib/python3.10/site-packages/ragas/testset/graph.py:292, in KnowledgeGraph.find_indirect_clusters.<locals>.dfs(node, cluster, depth, path)
#     288 if rel.source == node and rel.target not in cluster:
#     289     neighbor = rel.target
#     290 elif (
#     291     rel.bidirectional
# --> 292     and rel.target == node
#     293     and rel.source not in cluster
#     294 ):
#     295     neighbor = rel.source
#     297 if neighbor is not None:
#
# File ~/Desktop/assignment_clifford/env/lib/python3.10/site-packages/ragas/testset/graph.py:84, in Node.__eq__(self, other)
#      82 def __eq__(self, other: object) -> bool:
#      83     if isinstance(other, Node):
# ---> 84         return self.id == other.id
#      85     return False
#
# File ~/Desktop/assignment_clifford/env/lib/python3.10/uuid.py:239, in UUID.__eq__(self, other)
#     234     # is_safe was added in 3.7; it is also omitted when it is "unknown"
#     235     object.__setattr__(self, 'is_safe',
#     236                        SafeUUID(state['is_safe'])
#     237                        if 'is_safe' in state else SafeUUID.unknown)
# --> 239 def __eq__(self, other):
#     240     if isinstance(other, UUID):
#     241         return self.int == other.int
#
# KeyboardInterrupt:

# %%
dataset.to_pandas()

# %%
dataset.to_pandas().to_csv("../datasets/synthetic_dataset.csv")
