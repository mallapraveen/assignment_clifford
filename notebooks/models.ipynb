# %% [markdown]
# ### AWS Creds

# %%
import sys,os
import gimme_aws_creds.main
import gimme_aws_creds.ui

account_ids = sys.argv[1:] or [
    "123456789012",
    "120123456789",
]

pattern = "|".join(sorted(set(account_ids)))
pattern = "/:({}):/".format(pattern)
ui = gimme_aws_creds.ui.CLIUserInterface(argv=[sys.argv[0], "--roles", pattern])
creds = gimme_aws_creds.main.GimmeAWSCreds(ui=ui)

# Print out all selected roles:
for role in creds.aws_selected_roles:
    print(role)

# Generate credentials overriding profile name with `okta-<account_id>`
for data in creds.iter_selected_aws_credentials():
    arn = data["role"]["arn"]
    account_id = None
    for piece in arn.split(":"):
        if len(piece) == 12 and piece.isdigit():
            account_id = piece
            break

    if account_id is None:
        raise ValueError("Didn't find aws_account_id (12 digits) in {}".format(arn))

    data["profile"]["name"] = "okta-{}".format(account_id)
    creds.write_aws_creds_from_data(data)
os.environ["AWS_ACCESS_KEY_ID"] = data["credentials"]["aws_access_key_id"]
os.environ["AWS_SECRET_ACCESS_KEY"] = data["credentials"]["aws_secret_access_key"]
os.environ["AWS_SESSION_TOKEN"] = data["credentials"]["aws_session_token"]
data["credentials"]["aws_access_key_id"], data["credentials"][
    "aws_secret_access_key"
], data["credentials"]["aws_session_token"], data["credentials"]["aws_security_token"]
# Out:
# Okta Classic login flow enabled
# Using password from keyring for praveen.malla@dentsu.com
# Multi-factor Authentication required.
# Pick a factor:
# [0] Okta Verify App: SmartPhone_Android: OnePlus 13
# [1] Okta Verify App: SmartPhone_Android: Praveen Malla
# [2] token:software:totp( OKTA ) : praveen.malla@dentsu.com
# [3] token:software:totp( OKTA ) : praveen.malla@dentsu.com
# Selection: Okta Verify push sent...
# ERROR: AWS roles [/:(--f=/Users/pmalla01/Library/Jupyter/runtime/kernel-v3658dd511fcb8a9cd8c4a02debcd7165eb31ccf55.json):/] not found!
# Detected single role: arn:aws:iam::626635442901:role/MerkleSSOAIDevelopersRole
# RoleSet(idp='arn:aws:iam::626635442901:saml-provider/MerkleOktaProdSSO', role='arn:aws:iam::626635442901:role/MerkleSSOAIDevelopersRole', friendly_account_name='SingleAccountName', friendly_role_name='SingleRole')
# Saving arn:aws:iam::626635442901:role/MerkleSSOAIDevelopersRole as okta-626635442901
# ...

# %% [markdown]
# ### AWS

# %%
import os
import boto3
import json
# from dotenv import load_dotenv, find_dotenv

# _ = load_dotenv(find_dotenv())

session = boto3.Session()
bedrock = session.client(
    service_name="bedrock",
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    aws_session_token=os.getenv("AWS_SESSION_TOKEN"),
    region_name="us-east-1",
)
output_text = bedrock.list_foundation_models()

print(json.dumps(output_text, indent=4))
# Out:
# {
#     "ResponseMetadata": {
#         "RequestId": "7698d31f-250b-437a-b3c6-42afed60ae24",
#         "HTTPStatusCode": 200,
#         "HTTPHeaders": {
#             "date": "Tue, 08 Apr 2025 10:56:53 GMT",
#             "content-type": "application/json",
#             "content-length": "41306",
#             "connection": "keep-alive",
#             "x-amzn-requestid": "7698d31f-250b-437a-b3c6-42afed60ae24"
#         },
#         "RetryAttempts": 0
#     },
#     "modelSummaries": [
#         {
#             "modelArn": "arn:aws:bedrock:us-east-1::foundation-model/amazon.titan-tg1-large",
#             "modelId": "amazon.titan-tg1-large",
#             "modelName": "Titan Text Large",
#             "providerName": "Amazon",
#             "inputModalities": [
#                 "TEXT"
#             ],
#             "outputModalities": [
#                 "TEXT"
#             ],
#             "responseStreamingSupported": true,
#             "customizationsSupported": [],
# ...

# %%
import boto3

bedrock_runtime = boto3.client(
    service_name="bedrock-runtime",
    region_name="us-east-1",
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    aws_session_token=os.getenv("AWS_SESSION_TOKEN"),
)

# %%
from langchain_aws import ChatBedrock
model_id = "us.anthropic.claude-3-5-sonnet-20241022-v2:0"

claude_3_client = ChatBedrock(
    client=bedrock_runtime,
    model_id=model_id,
)

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# Invoke Example
messages = [
    ("human", "{question}"),
]

prompt = ChatPromptTemplate.from_messages(messages)

chain = prompt | claude_3_client | StrOutputParser()

# Chain Invoke
response = chain.invoke({"question": "Hi"})
print(response)
# Out:
# Hello! How can I help you today?
